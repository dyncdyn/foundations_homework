# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
from dotenv import load_dotenv
load_dotenv()
import os

API_KEY = os.getenv("DARKSKY_API_KEY")
API_KEY
# Out:
# '80f9cf4395301f0ba1ebadb4f00716aa'

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
URL = f'https://api.darksky.net/forecast/{API_KEY}/40.7675,114.8863'

# %%
response = requests.get(URL)
Home = response.json()
Home
# Out:
# {'latitude': 40.7675,
#  'longitude': 114.8863,
#  'timezone': 'Asia/Shanghai',
#  'currently': {'time': 1559959589,
#   'summary': 'Breezy',
#   'icon': 'wind',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 79.99,
#   'apparentTemperature': 79.99,
#   'dewPoint': 29.25,
#   'humidity': 0.16,
#   'pressure': 1004.57,
#   'windSpeed': 15.05,
#   'windGust': 33.28,
#   'windBearing': 292,
#   'cloudCover': 0.03,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 383.83},
#  'hourly': {'summary': 'Breezy until this evening.',
#   'icon': 'wind',
#   'data': [{'time': 1559959200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.67,
#     'apparentTemperature': 79.67,
#     'dewPoint': 29.17,
#     'humidity': 0.16,
#     'pressure': 1004.65,
#     'windSpeed': 14.79,
#     'windGust': 32.92,
#     'windBearing': 291,
#     'cloudCover': 0.03,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 383.49},
#    {'time': 1559962800,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.59,
#     'apparentTemperature': 82.59,
#     'dewPoint': 29.93,
#     'humidity': 0.15,
#     'pressure': 1003.9,
#     'windSpeed': 17.38,
#     'windGust': 36.26,
#     'windBearing': 299,
#     'cloudCover': 0.04,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 386.57},
#    {'time': 1559966400,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 84,
#     'apparentTemperature': 84,
#     'dewPoint': 29.55,
#     'humidity': 0.14,
#     'pressure': 1003.19,
#     'windSpeed': 18.72,
#     'windGust': 36.62,
#     'windBearing': 303,
#     'cloudCover': 0.04,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 383.13},
#    {'time': 1559970000,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 84.55,
#     'apparentTemperature': 84.55,
#     'dewPoint': 28.63,
#     'humidity': 0.13,
#     'pressure': 1002.52,
#     'windSpeed': 19.41,
#     'windGust': 35.13,
#     'windBearing': 304,
#     'cloudCover': 0.03,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 376.56},
#    {'time': 1559973600,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 84.32,
#     'apparentTemperature': 84.32,
#     'dewPoint': 28.1,
#     'humidity': 0.13,
#     'pressure': 1002,
#     'windSpeed': 19.78,
#     'windGust': 33.64,
#     'windBearing': 307,
#     'cloudCover': 0.02,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 371.42},
#    {'time': 1559977200,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 83.7,
#     'apparentTemperature': 83.7,
#     'dewPoint': 28.37,
#     'humidity': 0.13,
#     'pressure': 1001.63,
#     'windSpeed': 20.08,
#     'windGust': 32.92,
#     'windBearing': 311,
#     'cloudCover': 0.02,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 369.76},
#    {'time': 1559980800,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.56,
#     'apparentTemperature': 82.56,
#     'dewPoint': 29.12,
#     'humidity': 0.14,
#     'pressure': 1001.41,
#     'windSpeed': 20.07,
#     'windGust': 32.2,
#     'windBearing': 316,
#     'cloudCover': 0.01,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 369.71},
#    {'time': 1559984400,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.77,
#     'apparentTemperature': 81.77,
#     'dewPoint': 30.35,
#     'humidity': 0.15,
#     'pressure': 1001.46,
#     'windSpeed': 19.34,
#     'windGust': 31.02,
#     'windBearing': 322,
#     'cloudCover': 0.01,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 370.11},
#    {'time': 1559988000,
#     'summary': 'Breezy',
#     'icon': 'wind',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.54,
#     'apparentTemperature': 79.54,
#     'dewPoint': 32.4,
#     'humidity': 0.18,
#     'pressure': 1001.87,
#     'windSpeed': 17.37,
#     'windGust': 28.9,
#     'windBearing': 327,
#     'cloudCover': 0.01,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 370.77},
#    {'time': 1559991600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.61,
#     'apparentTemperature': 76.61,
#     'dewPoint': 34.84,
#     'humidity': 0.22,
#     'pressure': 1002.55,
#     'windSpeed': 14.68,
#     'windGust': 26.33,
#     'windBearing': 332,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 371.99},
#    {'time': 1559995200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.71,
#     'apparentTemperature': 73.71,
#     'dewPoint': 36.82,
#     'humidity': 0.26,
#     'pressure': 1003.33,
#     'windSpeed': 12.43,
#     'windGust': 24.31,
#     'windBearing': 335,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 373.04},
#    {'time': 1559998800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.49,
#     'apparentTemperature': 71.49,
#     'dewPoint': 37.83,
#     'humidity': 0.29,
#     'pressure': 1004.22,
#     'windSpeed': 11.23,
#     'windGust': 23.37,
#     'windBearing': 335,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 374.02},
#    {'time': 1560002400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.57,
#     'apparentTemperature': 69.57,
#     'dewPoint': 38.39,
#     'humidity': 0.32,
#     'pressure': 1005.2,
#     'windSpeed': 10.51,
#     'windGust': 22.96,
#     'windBearing': 332,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 374.9},
#    {'time': 1560006000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.73,
#     'apparentTemperature': 67.73,
#     'dewPoint': 38.97,
#     'humidity': 0.35,
#     'pressure': 1005.94,
#     'windSpeed': 9.91,
#     'windGust': 22.7,
#     'windBearing': 331,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 375.66},
#    {'time': 1560009600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.71,
#     'apparentTemperature': 65.71,
#     'dewPoint': 39.78,
#     'humidity': 0.39,
#     'pressure': 1006.27,
#     'windSpeed': 9.29,
#     'windGust': 22.6,
#     'windBearing': 332,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 376.57},
#    {'time': 1560013200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.85,
#     'apparentTemperature': 63.85,
#     'dewPoint': 40.58,
#     'humidity': 0.42,
#     'pressure': 1006.37,
#     'windSpeed': 8.8,
#     'windGust': 22.63,
#     'windBearing': 333,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 377.38},
#    {'time': 1560016800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.35,
#     'apparentTemperature': 62.35,
#     'dewPoint': 41.37,
#     'humidity': 0.46,
#     'pressure': 1006.52,
#     'windSpeed': 8.48,
#     'windGust': 22.27,
#     'windBearing': 333,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 377.25},
#    {'time': 1560020400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.71,
#     'apparentTemperature': 60.71,
#     'dewPoint': 42.04,
#     'humidity': 0.5,
#     'pressure': 1006.86,
#     'windSpeed': 8.24,
#     'windGust': 20.87,
#     'windBearing': 330,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 375.65},
#    {'time': 1560024000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.12,
#     'apparentTemperature': 59.12,
#     'dewPoint': 42.69,
#     'humidity': 0.54,
#     'pressure': 1007.26,
#     'windSpeed': 8.18,
#     'windGust': 19.07,
#     'windBearing': 324,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 373.05},
#    {'time': 1560027600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.54,
#     'apparentTemperature': 58.54,
#     'dewPoint': 43.19,
#     'humidity': 0.57,
#     'pressure': 1007.58,
#     'windSpeed': 8.69,
#     'windGust': 18.36,
#     'windBearing': 323,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 370.62},
#    {'time': 1560031200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.72,
#     'apparentTemperature': 59.72,
#     'dewPoint': 43.6,
#     'humidity': 0.55,
#     'pressure': 1007.8,
#     'windSpeed': 10.28,
#     'windGust': 19.82,
#     'windBearing': 330,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 368.79},
#    {'time': 1560034800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.62,
#     'apparentTemperature': 62.62,
#     'dewPoint': 43.92,
#     'humidity': 0.5,
#     'pressure': 1007.94,
#     'windSpeed': 12.43,
#     'windGust': 22.37,
#     'windBearing': 342,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 367.14},
#    {'time': 1560038400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.73,
#     'apparentTemperature': 65.73,
#     'dewPoint': 43.99,
#     'humidity': 0.45,
#     'pressure': 1007.91,
#     'windSpeed': 13.98,
#     'windGust': 24.19,
#     'windBearing': 352,
#     'cloudCover': 0,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 365.07},
#    {'time': 1560042000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.04,
#     'apparentTemperature': 69.04,
#     'dewPoint': 43.72,
#     'humidity': 0.4,
#     'pressure': 1007.63,
#     'windSpeed': 14.51,
#     'windGust': 24.58,
#     'windBearing': 358,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 362},
#    {'time': 1560045600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.49,
#     'apparentTemperature': 72.49,
#     'dewPoint': 43.21,
#     'humidity': 0.35,
#     'pressure': 1007.21,
#     'windSpeed': 14.51,
#     'windGust': 24.24,
#     'windBearing': 3,
#     'cloudCover': 0,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 358.51},
#    {'time': 1560049200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.21,
#     'apparentTemperature': 75.21,
#     'dewPoint': 42.64,
#     'humidity': 0.31,
#     'pressure': 1006.76,
#     'windSpeed': 14.17,
#     'windGust': 23.3,
#     'windBearing': 6,
#     'cloudCover': 0,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 355.71},
#    {'time': 1560052800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.53,
#     'apparentTemperature': 77.53,
#     'dewPoint': 42,
#     'humidity': 0.28,
#     'pressure': 1006.36,
#     'windSpeed': 13.46,
#     'windGust': 21.49,
#     'windBearing': 8,
#     'cloudCover': 0.03,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 354.12},
#    {'time': 1560056400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.28,
#     'apparentTemperature': 79.28,
#     'dewPoint': 41.29,
#     'humidity': 0.26,
#     'pressure': 1005.96,
#     'windSpeed': 12.46,
#     'windGust': 19.07,
#     'windBearing': 8,
#     'cloudCover': 0.07,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 353.22},
#    {'time': 1560060000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.64,
#     'apparentTemperature': 81.64,
#     'dewPoint': 40.69,
#     'humidity': 0.23,
#     'pressure': 1005.58,
#     'windSpeed': 11.61,
#     'windGust': 17.12,
#     'windBearing': 8,
#     'cloudCover': 0.1,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 352.55},
#    {'time': 1560063600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 83.29,
#     'apparentTemperature': 83.29,
#     'dewPoint': 40.24,
#     'humidity': 0.22,
#     'pressure': 1005.17,
#     'windSpeed': 11.29,
#     'windGust': 16.28,
#     'windBearing': 6,
#     'cloudCover': 0.12,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 352.34},
#    {'time': 1560067200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 84.29,
#     'apparentTemperature': 84.29,
#     'dewPoint': 39.91,
#     'humidity': 0.21,
#     'pressure': 1004.79,
#     'windSpeed': 11.11,
#     'windGust': 15.9,
#     'windBearing': 4,
#     'cloudCover': 0.12,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 352.26},
#    {'time': 1560070800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 84.05,
#     'apparentTemperature': 84.05,
#     'dewPoint': 39.67,
#     'humidity': 0.21,
#     'pressure': 1004.7,
#     'windSpeed': 10.53,
#     'windGust': 15.04,
#     'windBearing': 4,
#     'cloudCover': 0.12,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 351.11},
#    {'time': 1560074400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.11,
#     'apparentTemperature': 82.11,
#     'dewPoint': 39.47,
#     'humidity': 0.22,
#     'pressure': 1005.03,
#     'windSpeed': 9.14,
#     'windGust': 13.18,
#     'windBearing': 6,
#     'cloudCover': 0.11,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 347.78},
#    {'time': 1560078000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.99,
#     'apparentTemperature': 78.99,
#     'dewPoint': 39.34,
#     'humidity': 0.24,
#     'pressure': 1005.64,
#     'windSpeed': 7.35,
#     'windGust': 10.84,
#     'windBearing': 9,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 343.26},
#    {'time': 1560081600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.02,
#     'apparentTemperature': 76.02,
#     'dewPoint': 39.54,
#     'humidity': 0.27,
#     'pressure': 1006.36,
#     'windSpeed': 5.8,
#     'windGust': 8.77,
#     'windBearing': 11,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 339.29},
#    {'time': 1560085200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.36,
#     'apparentTemperature': 72.36,
#     'dewPoint': 40.27,
#     'humidity': 0.31,
#     'pressure': 1007.27,
#     'windSpeed': 4.75,
#     'windGust': 7.2,
#     'windBearing': 15,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.52},
#    {'time': 1560088800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.72,
#     'apparentTemperature': 68.72,
#     'dewPoint': 41.32,
#     'humidity': 0.37,
#     'pressure': 1008.28,
#     'windSpeed': 3.97,
#     'windGust': 5.88,
#     'windBearing': 17,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.15},
#    {'time': 1560092400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.39,
#     'apparentTemperature': 65.39,
#     'dewPoint': 42.06,
#     'humidity': 0.43,
#     'pressure': 1009.05,
#     'windSpeed': 3.41,
#     'windGust': 4.94,
#     'windBearing': 18,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 332.14},
#    {'time': 1560096000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.2,
#     'apparentTemperature': 63.2,
#     'dewPoint': 42.27,
#     'humidity': 0.46,
#     'pressure': 1009.38,
#     'windSpeed': 3.19,
#     'windGust': 4.51,
#     'windBearing': 13,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 330.62},
#    {'time': 1560099600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.65,
#     'apparentTemperature': 61.65,
#     'dewPoint': 42.19,
#     'humidity': 0.49,
#     'pressure': 1009.45,
#     'windSpeed': 3.18,
#     'windGust': 4.45,
#     'windBearing': 7,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 329.46},
#    {'time': 1560103200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.46,
#     'apparentTemperature': 60.46,
#     'dewPoint': 42.07,
#     'humidity': 0.51,
#     'pressure': 1009.5,
#     'windSpeed': 3.18,
#     'windGust': 4.44,
#     'windBearing': 1,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 328.45},
#    {'time': 1560106800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.83,
#     'apparentTemperature': 58.83,
#     'dewPoint': 41.98,
#     'humidity': 0.54,
#     'pressure': 1009.59,
#     'windSpeed': 3.12,
#     'windGust': 4.37,
#     'windBearing': 358,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 327.32},
#    {'time': 1560110400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.23,
#     'apparentTemperature': 57.23,
#     'dewPoint': 41.84,
#     'humidity': 0.56,
#     'pressure': 1009.66,
#     'windSpeed': 3.09,
#     'windGust': 4.34,
#     'windBearing': 356,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 326.14},
#    {'time': 1560114000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.27,
#     'apparentTemperature': 57.27,
#     'dewPoint': 41.8,
#     'humidity': 0.56,
#     'pressure': 1009.67,
#     'windSpeed': 3.07,
#     'windGust': 4.34,
#     'windBearing': 353,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 325.28},
#    {'time': 1560117600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.92,
#     'apparentTemperature': 60.92,
#     'dewPoint': 41.84,
#     'humidity': 0.49,
#     'pressure': 1009.64,
#     'windSpeed': 3.04,
#     'windGust': 4.2,
#     'windBearing': 349,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 324.95},
#    {'time': 1560121200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.81,
#     'apparentTemperature': 66.81,
#     'dewPoint': 41.92,
#     'humidity': 0.4,
#     'pressure': 1009.57,
#     'windSpeed': 3.01,
#     'windGust': 4.09,
#     'windBearing': 344,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 324.95},
#    {'time': 1560124800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.14,
#     'apparentTemperature': 72.14,
#     'dewPoint': 41.97,
#     'humidity': 0.34,
#     'pressure': 1009.36,
#     'windSpeed': 3.14,
#     'windGust': 4.4,
#     'windBearing': 342,
#     'cloudCover': 0.02,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 324.38},
#    {'time': 1560128400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.54,
#     'apparentTemperature': 75.54,
#     'dewPoint': 42.01,
#     'humidity': 0.3,
#     'pressure': 1009.03,
#     'windSpeed': 3.62,
#     'windGust': 5.62,
#     'windBearing': 344,
#     'cloudCover': 0.08,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 322.78},
#    {'time': 1560132000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.08,
#     'apparentTemperature': 78.08,
#     'dewPoint': 42.05,
#     'humidity': 0.28,
#     'pressure': 1008.55,
#     'windSpeed': 4.26,
#     'windGust': 7.28,
#     'windBearing': 349,
#     'cloudCover': 0.17,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 320.64}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures rising to 91°F on Friday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1559923200,
#     'summary': 'Breezy until evening.',
#     'icon': 'wind',
#     'sunriseTime': 1559940642,
#     'sunsetTime': 1559994665,
#     'moonPhase': 0.17,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 84.55,
#     'temperatureHighTime': 1559970000,
#     'temperatureLow': 58.54,
#     'temperatureLowTime': 1560027600,
#     'apparentTemperatureHigh': 84.55,
#     'apparentTemperatureHighTime': 1559970000,
#     'apparentTemperatureLow': 58.54,
#     'apparentTemperatureLowTime': 1560027600,
#     'dewPoint': 30.02,
#     'humidity': 0.22,
#     'pressure': 1004.82,
#     'windSpeed': 11.26,
#     'windGust': 36.62,
#     'windGustTime': 1559966400,
#     'windBearing': 311,
#     'cloudCover': 0.18,
#     'uvIndex': 8,
#     'uvIndexTime': 1559966400,
#     'visibility': 10,
#     'ozone': 372.7,
#     'temperatureMin': 56.69,
#     'temperatureMinTime': 1559941200,
#     'temperatureMax': 84.55,
#     'temperatureMaxTime': 1559970000,
#     'apparentTemperatureMin': 56.69,
#     'apparentTemperatureMinTime': 1559941200,
#     'apparentTemperatureMax': 84.55,
#     'apparentTemperatureMaxTime': 1559970000},
#    {'time': 1560009600,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1560027029,
#     'sunsetTime': 1560081100,
#     'moonPhase': 0.21,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560060000,
#     'precipProbability': 0,
#     'temperatureHigh': 84.29,
#     'temperatureHighTime': 1560067200,
#     'temperatureLow': 57.23,
#     'temperatureLowTime': 1560110400,
#     'apparentTemperatureHigh': 84.29,
#     'apparentTemperatureHighTime': 1560067200,
#     'apparentTemperatureLow': 57.23,
#     'apparentTemperatureLowTime': 1560110400,
#     'dewPoint': 41.52,
#     'humidity': 0.36,
#     'pressure': 1006.68,
#     'windSpeed': 9.44,
#     'windGust': 24.58,
#     'windGustTime': 1560042000,
#     'windBearing': 355,
#     'cloudCover': 0.04,
#     'uvIndex': 9,
#     'uvIndexTime': 1560052800,
#     'visibility': 10,
#     'ozone': 357.35,
#     'temperatureMin': 58.54,
#     'temperatureMinTime': 1560027600,
#     'temperatureMax': 84.29,
#     'temperatureMaxTime': 1560067200,
#     'apparentTemperatureMin': 58.54,
#     'apparentTemperatureMinTime': 1560027600,
#     'apparentTemperatureMax': 84.29,
#     'apparentTemperatureMaxTime': 1560067200},
#    {'time': 1560096000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560113418,
#     'sunsetTime': 1560167533,
#     'moonPhase': 0.25,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560135600,
#     'precipProbability': 0,
#     'temperatureHigh': 89.23,
#     'temperatureHighTime': 1560153600,
#     'temperatureLow': 60.52,
#     'temperatureLowTime': 1560196800,
#     'apparentTemperatureHigh': 89.23,
#     'apparentTemperatureHighTime': 1560153600,
#     'apparentTemperatureLow': 60.52,
#     'apparentTemperatureLowTime': 1560196800,
#     'dewPoint': 40.67,
#     'humidity': 0.33,
#     'pressure': 1007.59,
#     'windSpeed': 2.87,
#     'windGust': 8.26,
#     'windGustTime': 1560135600,
#     'windBearing': 353,
#     'cloudCover': 0.37,
#     'uvIndex': 8,
#     'uvIndexTime': 1560135600,
#     'visibility': 10,
#     'ozone': 323.95,
#     'temperatureMin': 57.23,
#     'temperatureMinTime': 1560110400,
#     'temperatureMax': 89.23,
#     'temperatureMaxTime': 1560153600,
#     'apparentTemperatureMin': 57.23,
#     'apparentTemperatureMinTime': 1560110400,
#     'apparentTemperatureMax': 89.23,
#     'apparentTemperatureMaxTime': 1560153600},
#    {'time': 1560182400,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560199810,
#     'sunsetTime': 1560253964,
#     'moonPhase': 0.29,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560236400,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 88.02,
#     'temperatureHighTime': 1560232800,
#     'temperatureLow': 62.16,
#     'temperatureLowTime': 1560286800,
#     'apparentTemperatureHigh': 88.02,
#     'apparentTemperatureHighTime': 1560232800,
#     'apparentTemperatureLow': 62.16,
#     'apparentTemperatureLowTime': 1560286800,
#     'dewPoint': 43.69,
#     'humidity': 0.34,
#     'pressure': 1006.74,
#     'windSpeed': 1.78,
#     'windGust': 12.95,
#     'windGustTime': 1560243600,
#     'windBearing': 107,
#     'cloudCover': 0.91,
#     'uvIndex': 4,
#     'uvIndexTime': 1560218400,
#     'visibility': 10,
#     'ozone': 328.55,
#     'temperatureMin': 60.52,
#     'temperatureMinTime': 1560196800,
#     'temperatureMax': 88.02,
#     'temperatureMaxTime': 1560232800,
#     'apparentTemperatureMin': 60.52,
#     'apparentTemperatureMinTime': 1560196800,
#     'apparentTemperatureMax': 88.02,
#     'apparentTemperatureMaxTime': 1560232800},
#    {'time': 1560268800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560286203,
#     'sunsetTime': 1560340394,
#     'moonPhase': 0.32,
#     'precipIntensity': 0.0014,
#     'precipIntensityMax': 0.0136,
#     'precipIntensityMaxTime': 1560319200,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperatureHigh': 88.34,
#     'temperatureHighTime': 1560315600,
#     'temperatureLow': 66.82,
#     'temperatureLowTime': 1560373200,
#     'apparentTemperatureHigh': 88.34,
#     'apparentTemperatureHighTime': 1560315600,
#     'apparentTemperatureLow': 66.82,
#     'apparentTemperatureLowTime': 1560373200,
#     'dewPoint': 50.7,
#     'humidity': 0.42,
#     'pressure': 1005.72,
#     'windSpeed': 2.69,
#     'windGust': 9.4,
#     'windGustTime': 1560340800,
#     'windBearing': 188,
#     'cloudCover': 0.86,
#     'uvIndex': 5,
#     'uvIndexTime': 1560308400,
#     'visibility': 10,
#     'ozone': 340.99,
#     'temperatureMin': 62.16,
#     'temperatureMinTime': 1560286800,
#     'temperatureMax': 88.34,
#     'temperatureMaxTime': 1560315600,
#     'apparentTemperatureMin': 62.16,
#     'apparentTemperatureMinTime': 1560286800,
#     'apparentTemperatureMax': 88.34,
#     'apparentTemperatureMaxTime': 1560315600},
#    {'time': 1560355200,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1560372598,
#     'sunsetTime': 1560426823,
#     'moonPhase': 0.36,
#     'precipIntensity': 0.0037,
#     'precipIntensityMax': 0.025,
#     'precipIntensityMaxTime': 1560405600,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperatureHigh': 86.59,
#     'temperatureHighTime': 1560405600,
#     'temperatureLow': 63.78,
#     'temperatureLowTime': 1560456000,
#     'apparentTemperatureHigh': 86.59,
#     'apparentTemperatureHighTime': 1560405600,
#     'apparentTemperatureLow': 63.78,
#     'apparentTemperatureLowTime': 1560456000,
#     'dewPoint': 50.25,
#     'humidity': 0.42,
#     'pressure': 1006.85,
#     'windSpeed': 4.21,
#     'windGust': 15.66,
#     'windGustTime': 1560376800,
#     'windBearing': 2,
#     'cloudCover': 0.04,
#     'uvIndex': 8,
#     'uvIndexTime': 1560398400,
#     'visibility': 10,
#     'ozone': 365.11,
#     'temperatureMin': 66.82,
#     'temperatureMinTime': 1560373200,
#     'temperatureMax': 86.59,
#     'temperatureMaxTime': 1560405600,
#     'apparentTemperatureMin': 66.82,
#     'apparentTemperatureMinTime': 1560373200,
#     'apparentTemperatureMax': 86.59,
#     'apparentTemperatureMaxTime': 1560405600},
#    {'time': 1560441600,
#     'summary': 'Mostly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560458995,
#     'sunsetTime': 1560513249,
#     'moonPhase': 0.39,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 91.39,
#     'temperatureHighTime': 1560499200,
#     'temperatureLow': 67.78,
#     'temperatureLowTime': 1560546000,
#     'apparentTemperatureHigh': 91.39,
#     'apparentTemperatureHighTime': 1560499200,
#     'apparentTemperatureLow': 67.78,
#     'apparentTemperatureLowTime': 1560546000,
#     'dewPoint': 45.55,
#     'humidity': 0.33,
#     'pressure': 1005.91,
#     'windSpeed': 2.39,
#     'windGust': 8.26,
#     'windGustTime': 1560502800,
#     'windBearing': 165,
#     'cloudCover': 0.34,
#     'uvIndex': 9,
#     'uvIndexTime': 1560481200,
#     'visibility': 10,
#     'ozone': 333.48,
#     'temperatureMin': 63.78,
#     'temperatureMinTime': 1560456000,
#     'temperatureMax': 91.39,
#     'temperatureMaxTime': 1560499200,
#     'apparentTemperatureMin': 63.78,
#     'apparentTemperatureMinTime': 1560456000,
#     'apparentTemperatureMax': 91.39,
#     'apparentTemperatureMaxTime': 1560499200},
#    {'time': 1560528000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560545394,
#     'sunsetTime': 1560599674,
#     'moonPhase': 0.43,
#     'precipIntensity': 0.0014,
#     'precipIntensityMax': 0.0057,
#     'precipIntensityMaxTime': 1560571200,
#     'precipProbability': 0.23,
#     'precipType': 'rain',
#     'temperatureHigh': 87.66,
#     'temperatureHighTime': 1560578400,
#     'temperatureLow': 67.78,
#     'temperatureLowTime': 1560632400,
#     'apparentTemperatureHigh': 87.66,
#     'apparentTemperatureHighTime': 1560578400,
#     'apparentTemperatureLow': 67.78,
#     'apparentTemperatureLowTime': 1560632400,
#     'dewPoint': 51.6,
#     'humidity': 0.4,
#     'pressure': 1003.24,
#     'windSpeed': 2.54,
#     'windGust': 13.08,
#     'windGustTime': 1560564000,
#     'windBearing': 184,
#     'cloudCover': 0.83,
#     'uvIndex': 5,
#     'uvIndexTime': 1560574800,
#     'visibility': 10,
#     'ozone': 331.8,
#     'temperatureMin': 67.78,
#     'temperatureMinTime': 1560546000,
#     'temperatureMax': 87.66,
#     'temperatureMaxTime': 1560578400,
#     'apparentTemperatureMin': 67.78,
#     'apparentTemperatureMinTime': 1560546000,
#     'apparentTemperatureMax': 87.66,
#     'apparentTemperatureMaxTime': 1560578400}]},
#  'flags': {'sources': ['cmc', 'gfs', 'icon', 'isd', 'madis'],
#   'nearest-station': 1.085,
#   'units': 'us'},
#  'offset': 8}

# %%
Home['timezone']
# Out:
# 'Asia/Shanghai'

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
Home['currently']['windSpeed']
# Out:
# 11.19

# %%
TemDiff = Home['currently']['temperature']-Home['currently']['apparentTemperature']
TemDiff
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
Daily1 = Home['daily']['data'][0]
Daily1
# Out:
# {'time': 1559923200,
#  'summary': 'Breezy until evening.',
#  'icon': 'wind',
#  'sunriseTime': 1559940642,
#  'sunsetTime': 1559994665,
#  'moonPhase': 0.17,
#  'precipIntensity': 0,
#  'precipIntensityMax': 0,
#  'precipProbability': 0,
#  'temperatureHigh': 84.58,
#  'temperatureHighTime': 1559970000,
#  'temperatureLow': 58.54,
#  'temperatureLowTime': 1560027600,
#  'apparentTemperatureHigh': 84.58,
#  'apparentTemperatureHighTime': 1559970000,
#  'apparentTemperatureLow': 58.54,
#  'apparentTemperatureLowTime': 1560027600,
#  'dewPoint': 30.02,
#  'humidity': 0.22,
#  'pressure': 1004.82,
#  'windSpeed': 11.26,
#  'windGust': 36.62,
#  'windGustTime': 1559966400,
#  'windBearing': 311,
#  'cloudCover': 0.18,
#  'uvIndex': 8,
#  'uvIndexTime': 1559966400,
#  'visibility': 10,
#  'ozone': 372.7,
#  'temperatureMin': 57.27,
#  'temperatureMinTime': 1559941200,
#  'temperatureMax': 84.58,
#  'temperatureMaxTime': 1559970000,
#  'apparentTemperatureMin': 57.27,
#  'apparentTemperatureMinTime': 1559941200,
#  'apparentTemperatureMax': 84.58,
#  'apparentTemperatureMaxTime': 1559970000}

# %%
Moon = Daily1['moonPhase']
Moon
# Out:
# 0.17

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
TemDiff_today = Daily1['temperatureHigh'] - Daily1['temperatureLow']
TemDiff_today
# Out:
# 26.04

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
Daily = Home['daily']['data']
for day in Daily:
    hightemp = day['temperatureHigh']
    if hightemp > 80:
        print(f'The high temperature is {hightemp}, and it is hot.')
    elif hightemp < 50:
        print(f'The high temperature is {hightemp}, and it is cold.')
    else:
        print(f'The high temperature is {hightemp}, and it is warm.')
# Out:
# The high temperature is 84.58, and it is hot.
# The high temperature is 84.31, and it is hot.
# The high temperature is 89.22, and it is hot.
# The high temperature is 88.01, and it is hot.
# The high temperature is 88.34, and it is hot.
# The high temperature is 86.59, and it is hot.
# The high temperature is 91.39, and it is hot.
# The high temperature is 87.65, and it is hot.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
Date = []
HighTemp = []

for day in Daily:
    date = day['time']
    Date.append(date)
    hightemp = day['temperatureHigh']
    HighTemp.append(hightemp)

NextWeek = list(zip(HighTemp,Date))
Hottest = max(NextWeek)

Hottest
# Out:
# (91.39, 1560441600)

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918')
Miami = response.json()
Miami
# Out:
# {'latitude': 25.7617,
#  'longitude': -80.1918,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1559959701,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'nearestStormDistance': 20,
#   'nearestStormBearing': 37,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 77.69,
#   'apparentTemperature': 79.31,
#   'dewPoint': 73.91,
#   'humidity': 0.88,
#   'pressure': 1012.85,
#   'windSpeed': 6.02,
#   'windGust': 6.3,
#   'windBearing': 127,
#   'cloudCover': 0.74,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 281.04},
#  'minutely': {'summary': 'Humid and mostly cloudy for the hour.',
#   'icon': 'partly-cloudy-night',
#   'data': [{'time': 1559959680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559959740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559959800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559959860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559959920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559959980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559960940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962020,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.005,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962080,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.005,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962200,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.004,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962620,
#     'precipIntensity': 0.005,
#     'precipIntensityError': 0.004,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962680,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.006,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559962860,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.005,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962920,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559962980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559963040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559963100,
#     'precipIntensity': 0.011,
#     'precipIntensityError': 0.03,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559963160,
#     'precipIntensity': 0.009,
#     'precipIntensityError': 0.023,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559963220,
#     'precipIntensity': 0.008,
#     'precipIntensityError': 0.022,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1559963280,
#     'precipIntensity': 0.006,
#     'precipIntensityError': 0.005,
#     'precipProbability': 0.01,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Light rain starting tomorrow afternoon, continuing until tomorrow evening.',
#   'icon': 'rain',
#   'data': [{'time': 1559959200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.71,
#     'apparentTemperature': 79.32,
#     'dewPoint': 73.89,
#     'humidity': 0.88,
#     'pressure': 1012.87,
#     'windSpeed': 6.06,
#     'windGust': 6.29,
#     'windBearing': 126,
#     'cloudCover': 0.76,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 281.01},
#    {'time': 1559962800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 77.62,
#     'apparentTemperature': 79.25,
#     'dewPoint': 74.02,
#     'humidity': 0.89,
#     'pressure': 1012.7,
#     'windSpeed': 5.81,
#     'windGust': 6.31,
#     'windBearing': 132,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 281.22},
#    {'time': 1559966400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 80.03,
#     'apparentTemperature': 84.69,
#     'dewPoint': 74.37,
#     'humidity': 0.83,
#     'pressure': 1012.74,
#     'windSpeed': 6.68,
#     'windGust': 7.71,
#     'windBearing': 163,
#     'cloudCover': 0.69,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 281.64},
#    {'time': 1559970000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 81.65,
#     'apparentTemperature': 87.76,
#     'dewPoint': 74.56,
#     'humidity': 0.79,
#     'pressure': 1012.49,
#     'windSpeed': 8.58,
#     'windGust': 11.6,
#     'windBearing': 180,
#     'cloudCover': 0.61,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 282.02},
#    {'time': 1559973600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 79.88,
#     'apparentTemperature': 84.49,
#     'dewPoint': 74.61,
#     'humidity': 0.84,
#     'pressure': 1012.41,
#     'windSpeed': 8.95,
#     'windGust': 12.38,
#     'windBearing': 184,
#     'cloudCover': 0.5,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 282.49},
#    {'time': 1559977200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 78.24,
#     'apparentTemperature': 79.94,
#     'dewPoint': 74.67,
#     'humidity': 0.89,
#     'pressure': 1012.28,
#     'windSpeed': 9.19,
#     'windGust': 13.19,
#     'windBearing': 186,
#     'cloudCover': 0.61,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 282.89},
#    {'time': 1559980800,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0024,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 76.81,
#     'apparentTemperature': 78.58,
#     'dewPoint': 74.79,
#     'humidity': 0.94,
#     'pressure': 1012.01,
#     'windSpeed': 9.44,
#     'windGust': 14.63,
#     'windBearing': 189,
#     'cloudCover': 0.62,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 283.41},
#    {'time': 1559984400,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0026,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 76.86,
#     'apparentTemperature': 78.64,
#     'dewPoint': 74.8,
#     'humidity': 0.93,
#     'pressure': 1011.86,
#     'windSpeed': 9.21,
#     'windGust': 14.73,
#     'windBearing': 193,
#     'cloudCover': 0.62,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 283.87},
#    {'time': 1559988000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 76.91,
#     'apparentTemperature': 78.71,
#     'dewPoint': 75.01,
#     'humidity': 0.94,
#     'pressure': 1012.05,
#     'windSpeed': 8.96,
#     'windGust': 14.71,
#     'windBearing': 199,
#     'cloudCover': 0.48,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 284.03},
#    {'time': 1559991600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0022,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 77.53,
#     'apparentTemperature': 79.33,
#     'dewPoint': 75.17,
#     'humidity': 0.92,
#     'pressure': 1012.46,
#     'windSpeed': 8.69,
#     'windGust': 14.77,
#     'windBearing': 205,
#     'cloudCover': 0.42,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 284.25},
#    {'time': 1559995200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 78.92,
#     'apparentTemperature': 82.66,
#     'dewPoint': 75.26,
#     'humidity': 0.89,
#     'pressure': 1012.91,
#     'windSpeed': 8.44,
#     'windGust': 14.04,
#     'windBearing': 209,
#     'cloudCover': 0.32,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 284.58},
#    {'time': 1559998800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 81.94,
#     'apparentTemperature': 88.47,
#     'dewPoint': 74.88,
#     'humidity': 0.79,
#     'pressure': 1013.38,
#     'windSpeed': 7.97,
#     'windGust': 12.71,
#     'windBearing': 207,
#     'cloudCover': 0.27,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 285.25},
#    {'time': 1560002400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 84.38,
#     'apparentTemperature': 91.88,
#     'dewPoint': 74.2,
#     'humidity': 0.72,
#     'pressure': 1013.87,
#     'windSpeed': 6.92,
#     'windGust': 10.2,
#     'windBearing': 201,
#     'cloudCover': 0.26,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 286.13},
#    {'time': 1560006000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 86.37,
#     'apparentTemperature': 94.29,
#     'dewPoint': 73.71,
#     'humidity': 0.66,
#     'pressure': 1014.09,
#     'windSpeed': 6.42,
#     'windGust': 8.76,
#     'windBearing': 197,
#     'cloudCover': 0.28,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 286.79},
#    {'time': 1560009600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0063,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 87.22,
#     'apparentTemperature': 94.58,
#     'dewPoint': 72.81,
#     'humidity': 0.62,
#     'pressure': 1014.09,
#     'windSpeed': 6.92,
#     'windGust': 8.11,
#     'windBearing': 186,
#     'cloudCover': 0.47,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 286.84},
#    {'time': 1560013200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0215,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'temperature': 89.55,
#     'apparentTemperature': 97.73,
#     'dewPoint': 72.94,
#     'humidity': 0.58,
#     'pressure': 1013.77,
#     'windSpeed': 8.17,
#     'windGust': 9.17,
#     'windBearing': 177,
#     'cloudCover': 0.62,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 286.87},
#    {'time': 1560016800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0385,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 91.14,
#     'apparentTemperature': 99.85,
#     'dewPoint': 73.03,
#     'humidity': 0.56,
#     'pressure': 1013.48,
#     'windSpeed': 9.24,
#     'windGust': 10.23,
#     'windBearing': 170,
#     'cloudCover': 0.71,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 286.69},
#    {'time': 1560020400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0442,
#     'precipProbability': 0.22,
#     'precipType': 'rain',
#     'temperature': 91.44,
#     'apparentTemperature': 100.15,
#     'dewPoint': 72.95,
#     'humidity': 0.55,
#     'pressure': 1013.23,
#     'windSpeed': 9.98,
#     'windGust': 11.17,
#     'windBearing': 172,
#     'cloudCover': 0.72,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 286.47},
#    {'time': 1560024000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0435,
#     'precipProbability': 0.25,
#     'precipType': 'rain',
#     'temperature': 90.98,
#     'apparentTemperature': 99.44,
#     'dewPoint': 72.83,
#     'humidity': 0.56,
#     'pressure': 1012.98,
#     'windSpeed': 10.54,
#     'windGust': 12.12,
#     'windBearing': 177,
#     'cloudCover': 0.67,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 286.2},
#    {'time': 1560027600,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0416,
#     'precipProbability': 0.26,
#     'precipType': 'rain',
#     'temperature': 89.96,
#     'apparentTemperature': 98.09,
#     'dewPoint': 72.79,
#     'humidity': 0.57,
#     'pressure': 1012.88,
#     'windSpeed': 10.75,
#     'windGust': 12.45,
#     'windBearing': 180,
#     'cloudCover': 0.63,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 286.19},
#    {'time': 1560031200,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0401,
#     'precipProbability': 0.26,
#     'precipType': 'rain',
#     'temperature': 88.67,
#     'apparentTemperature': 96.45,
#     'dewPoint': 72.8,
#     'humidity': 0.6,
#     'pressure': 1013.04,
#     'windSpeed': 10.35,
#     'windGust': 11.71,
#     'windBearing': 175,
#     'cloudCover': 0.62,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 286.51},
#    {'time': 1560034800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0393,
#     'precipProbability': 0.27,
#     'precipType': 'rain',
#     'temperature': 87.2,
#     'apparentTemperature': 94.59,
#     'dewPoint': 72.86,
#     'humidity': 0.63,
#     'pressure': 1013.33,
#     'windSpeed': 9.56,
#     'windGust': 10.43,
#     'windBearing': 167,
#     'cloudCover': 0.62,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 286.97},
#    {'time': 1560038400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0343,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'temperature': 86,
#     'apparentTemperature': 93.1,
#     'dewPoint': 72.96,
#     'humidity': 0.65,
#     'pressure': 1013.72,
#     'windSpeed': 8.99,
#     'windGust': 9.76,
#     'windBearing': 165,
#     'cloudCover': 0.61,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.63},
#    {'time': 1560042000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.018,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'temperature': 84.96,
#     'apparentTemperature': 91.82,
#     'dewPoint': 73.13,
#     'humidity': 0.68,
#     'pressure': 1014.26,
#     'windSpeed': 8.8,
#     'windGust': 10.23,
#     'windBearing': 169,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 288.18},
#    {'time': 1560045600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 84.04,
#     'apparentTemperature': 90.7,
#     'dewPoint': 73.36,
#     'humidity': 0.7,
#     'pressure': 1014.87,
#     'windSpeed': 8.69,
#     'windGust': 11.12,
#     'windBearing': 175,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 288.93},
#    {'time': 1560049200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 83.13,
#     'apparentTemperature': 89.51,
#     'dewPoint': 73.57,
#     'humidity': 0.73,
#     'pressure': 1015.25,
#     'windSpeed': 8.55,
#     'windGust': 11.75,
#     'windBearing': 180,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.69},
#    {'time': 1560052800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 82.51,
#     'apparentTemperature': 88.66,
#     'dewPoint': 73.72,
#     'humidity': 0.75,
#     'pressure': 1015.17,
#     'windSpeed': 8.45,
#     'windGust': 11.91,
#     'windBearing': 182,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.69},
#    {'time': 1560056400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0008,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 82.08,
#     'apparentTemperature': 88.07,
#     'dewPoint': 73.87,
#     'humidity': 0.76,
#     'pressure': 1014.84,
#     'windSpeed': 8.39,
#     'windGust': 11.91,
#     'windBearing': 183,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.65},
#    {'time': 1560060000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 80.24,
#     'apparentTemperature': 84.97,
#     'dewPoint': 74.05,
#     'humidity': 0.82,
#     'pressure': 1014.53,
#     'windSpeed': 8.31,
#     'windGust': 11.93,
#     'windBearing': 184,
#     'cloudCover': 0.54,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 292.66},
#    {'time': 1560063600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0031,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 78.54,
#     'apparentTemperature': 81.66,
#     'dewPoint': 74.38,
#     'humidity': 0.87,
#     'pressure': 1014.21,
#     'windSpeed': 8.19,
#     'windGust': 12.12,
#     'windBearing': 189,
#     'cloudCover': 0.5,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 293.47},
#    {'time': 1560067200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0107,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 77.98,
#     'apparentTemperature': 79.69,
#     'dewPoint': 74.71,
#     'humidity': 0.9,
#     'pressure': 1013.92,
#     'windSpeed': 8.07,
#     'windGust': 12.37,
#     'windBearing': 194,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.05},
#    {'time': 1560070800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0165,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 78.03,
#     'apparentTemperature': 79.77,
#     'dewPoint': 74.9,
#     'humidity': 0.9,
#     'pressure': 1013.82,
#     'windSpeed': 7.95,
#     'windGust': 12.61,
#     'windBearing': 197,
#     'cloudCover': 0.41,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.79},
#    {'time': 1560074400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0099,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 78.19,
#     'apparentTemperature': 79.92,
#     'dewPoint': 74.88,
#     'humidity': 0.9,
#     'pressure': 1014.06,
#     'windSpeed': 7.9,
#     'windGust': 12.86,
#     'windBearing': 195,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 295.74},
#    {'time': 1560078000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 78.68,
#     'apparentTemperature': 82.02,
#     'dewPoint': 74.72,
#     'humidity': 0.88,
#     'pressure': 1014.53,
#     'windSpeed': 7.89,
#     'windGust': 13.07,
#     'windBearing': 192,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.71},
#    {'time': 1560081600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 79.82,
#     'apparentTemperature': 84.35,
#     'dewPoint': 74.51,
#     'humidity': 0.84,
#     'pressure': 1014.98,
#     'windSpeed': 7.84,
#     'windGust': 12.98,
#     'windBearing': 189,
#     'cloudCover': 0.26,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 297.52},
#    {'time': 1560085200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 82.22,
#     'apparentTemperature': 88.51,
#     'dewPoint': 74.21,
#     'humidity': 0.77,
#     'pressure': 1015.51,
#     'windSpeed': 7.59,
#     'windGust': 12.25,
#     'windBearing': 185,
#     'cloudCover': 0.22,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 298.26},
#    {'time': 1560088800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0036,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 84.37,
#     'apparentTemperature': 91.58,
#     'dewPoint': 73.85,
#     'humidity': 0.71,
#     'pressure': 1016.03,
#     'windSpeed': 7.3,
#     'windGust': 11.25,
#     'windBearing': 179,
#     'cloudCover': 0.19,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 298.74},
#    {'time': 1560092400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0075,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 85.98,
#     'apparentTemperature': 93.59,
#     'dewPoint': 73.55,
#     'humidity': 0.67,
#     'pressure': 1016.38,
#     'windSpeed': 7.48,
#     'windGust': 10.73,
#     'windBearing': 175,
#     'cloudCover': 0.18,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 298.92},
#    {'time': 1560096000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0119,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 87.52,
#     'apparentTemperature': 95.45,
#     'dewPoint': 73.32,
#     'humidity': 0.63,
#     'pressure': 1016.46,
#     'windSpeed': 8.51,
#     'windGust': 11,
#     'windBearing': 171,
#     'cloudCover': 0.24,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 298.54},
#    {'time': 1560099600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.017,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 89.99,
#     'apparentTemperature': 98.43,
#     'dewPoint': 73.08,
#     'humidity': 0.58,
#     'pressure': 1016.3,
#     'windSpeed': 9.93,
#     'windGust': 11.68,
#     'windBearing': 167,
#     'cloudCover': 0.35,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 297.76},
#    {'time': 1560103200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0223,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'temperature': 91.3,
#     'apparentTemperature': 99.94,
#     'dewPoint': 72.93,
#     'humidity': 0.55,
#     'pressure': 1016.09,
#     'windSpeed': 11.04,
#     'windGust': 12.47,
#     'windBearing': 166,
#     'cloudCover': 0.46,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 297.09},
#    {'time': 1560106800,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.031,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'temperature': 91.01,
#     'apparentTemperature': 99.52,
#     'dewPoint': 72.88,
#     'humidity': 0.56,
#     'pressure': 1015.75,
#     'windSpeed': 11.59,
#     'windGust': 13.39,
#     'windBearing': 168,
#     'cloudCover': 0.58,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 296.49},
#    {'time': 1560110400,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.042,
#     'precipProbability': 0.27,
#     'precipType': 'rain',
#     'temperature': 89.99,
#     'apparentTemperature': 98.24,
#     'dewPoint': 72.89,
#     'humidity': 0.57,
#     'pressure': 1015.33,
#     'windSpeed': 11.86,
#     'windGust': 14.4,
#     'windBearing': 172,
#     'cloudCover': 0.71,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 295.87},
#    {'time': 1560114000,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0439,
#     'precipProbability': 0.29,
#     'precipType': 'rain',
#     'temperature': 88.6,
#     'apparentTemperature': 96.48,
#     'dewPoint': 72.92,
#     'humidity': 0.6,
#     'pressure': 1015.11,
#     'windSpeed': 11.83,
#     'windGust': 15.02,
#     'windBearing': 176,
#     'cloudCover': 0.78,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 295.55},
#    {'time': 1560117600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0277,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'temperature': 87.38,
#     'apparentTemperature': 94.98,
#     'dewPoint': 73.01,
#     'humidity': 0.63,
#     'pressure': 1015.17,
#     'windSpeed': 11.46,
#     'windGust': 15.13,
#     'windBearing': 181,
#     'cloudCover': 0.7,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 295.7},
#    {'time': 1560121200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0136,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'temperature': 86.23,
#     'apparentTemperature': 93.54,
#     'dewPoint': 73.12,
#     'humidity': 0.65,
#     'pressure': 1015.46,
#     'windSpeed': 10.81,
#     'windGust': 14.88,
#     'windBearing': 185,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.06},
#    {'time': 1560124800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0114,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperature': 85.43,
#     'apparentTemperature': 92.55,
#     'dewPoint': 73.23,
#     'humidity': 0.67,
#     'pressure': 1015.75,
#     'windSpeed': 10.19,
#     'windGust': 14.58,
#     'windBearing': 187,
#     'cloudCover': 0.5,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.39},
#    {'time': 1560128400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.009,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 84.67,
#     'apparentTemperature': 91.64,
#     'dewPoint': 73.4,
#     'humidity': 0.69,
#     'pressure': 1016.11,
#     'windSpeed': 9.73,
#     'windGust': 14.23,
#     'windBearing': 187,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.88},
#    {'time': 1560132000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0053,
#     'precipProbability': 0.11,
#     'precipType': 'rain',
#     'temperature': 83.89,
#     'apparentTemperature': 90.65,
#     'dewPoint': 73.57,
#     'humidity': 0.71,
#     'pressure': 1016.49,
#     'windSpeed': 9.34,
#     'windGust': 13.82,
#     'windBearing': 186,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.27}]},
#  'daily': {'summary': 'Light rain throughout the week, with high temperatures falling to 89°F next Friday.',
#   'icon': 'rain',
#   'data': [{'time': 1559880000,
#     'summary': 'Heavy rain in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1559903417,
#     'sunsetTime': 1559952718,
#     'moonPhase': 0.15,
#     'precipIntensity': 0.0279,
#     'precipIntensityMax': 0.559,
#     'precipIntensityMaxTime': 1559948400,
#     'precipProbability': 0.92,
#     'precipType': 'rain',
#     'temperatureHigh': 91.95,
#     'temperatureHighTime': 1559930400,
#     'temperatureLow': 76.81,
#     'temperatureLowTime': 1559980800,
#     'apparentTemperatureHigh': 102.11,
#     'apparentTemperatureHighTime': 1559930400,
#     'apparentTemperatureLow': 78.58,
#     'apparentTemperatureLowTime': 1559980800,
#     'dewPoint': 73.76,
#     'humidity': 0.76,
#     'pressure': 1012.63,
#     'windSpeed': 5.84,
#     'windGust': 13.16,
#     'windGustTime': 1559934000,
#     'windBearing': 162,
#     'cloudCover': 0.59,
#     'uvIndex': 8,
#     'uvIndexTime': 1559926800,
#     'visibility': 9.42,
#     'ozone': 282.6,
#     'temperatureMin': 77.62,
#     'temperatureMinTime': 1559962800,
#     'temperatureMax': 91.95,
#     'temperatureMaxTime': 1559930400,
#     'apparentTemperatureMin': 79.25,
#     'apparentTemperatureMinTime': 1559962800,
#     'apparentTemperatureMax': 102.11,
#     'apparentTemperatureMaxTime': 1559930400},
#    {'time': 1559966400,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1559989815,
#     'sunsetTime': 1560039142,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.0149,
#     'precipIntensityMax': 0.0442,
#     'precipIntensityMaxTime': 1560020400,
#     'precipProbability': 0.86,
#     'precipType': 'rain',
#     'temperatureHigh': 91.44,
#     'temperatureHighTime': 1560020400,
#     'temperatureLow': 77.98,
#     'temperatureLowTime': 1560067200,
#     'apparentTemperatureHigh': 100.15,
#     'apparentTemperatureHighTime': 1560020400,
#     'apparentTemperatureLow': 79.69,
#     'apparentTemperatureLowTime': 1560067200,
#     'dewPoint': 73.84,
#     'humidity': 0.73,
#     'pressure': 1013.23,
#     'windSpeed': 8.52,
#     'windGust': 14.77,
#     'windGustTime': 1559991600,
#     'windBearing': 183,
#     'cloudCover': 0.54,
#     'uvIndex': 8,
#     'uvIndexTime': 1560009600,
#     'visibility': 10,
#     'ozone': 285.61,
#     'temperatureMin': 76.81,
#     'temperatureMinTime': 1559980800,
#     'temperatureMax': 91.44,
#     'temperatureMaxTime': 1560020400,
#     'apparentTemperatureMin': 78.58,
#     'apparentTemperatureMinTime': 1559980800,
#     'apparentTemperatureMax': 100.15,
#     'apparentTemperatureMaxTime': 1560020400},
#    {'time': 1560052800,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560076214,
#     'sunsetTime': 1560125565,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0123,
#     'precipIntensityMax': 0.0439,
#     'precipIntensityMaxTime': 1560114000,
#     'precipProbability': 0.74,
#     'precipType': 'rain',
#     'temperatureHigh': 91.3,
#     'temperatureHighTime': 1560103200,
#     'temperatureLow': 77.06,
#     'temperatureLowTime': 1560153600,
#     'apparentTemperatureHigh': 99.94,
#     'apparentTemperatureHighTime': 1560103200,
#     'apparentTemperatureLow': 78.7,
#     'apparentTemperatureLowTime': 1560153600,
#     'dewPoint': 73.73,
#     'humidity': 0.72,
#     'pressure': 1015.37,
#     'windSpeed': 9.08,
#     'windGust': 15.13,
#     'windGustTime': 1560117600,
#     'windBearing': 182,
#     'cloudCover': 0.42,
#     'uvIndex': 9,
#     'uvIndexTime': 1560096000,
#     'visibility': 10,
#     'ozone': 296.01,
#     'temperatureMin': 77.98,
#     'temperatureMinTime': 1560067200,
#     'temperatureMax': 91.3,
#     'temperatureMaxTime': 1560103200,
#     'apparentTemperatureMin': 79.69,
#     'apparentTemperatureMinTime': 1560067200,
#     'apparentTemperatureMax': 99.94,
#     'apparentTemperatureMaxTime': 1560103200},
#    {'time': 1560139200,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560162614,
#     'sunsetTime': 1560211987,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0077,
#     'precipIntensityMax': 0.0133,
#     'precipIntensityMaxTime': 1560189600,
#     'precipProbability': 0.62,
#     'precipType': 'rain',
#     'temperatureHigh': 91.15,
#     'temperatureHighTime': 1560193200,
#     'temperatureLow': 78.3,
#     'temperatureLowTime': 1560240000,
#     'apparentTemperatureHigh': 98.76,
#     'apparentTemperatureHighTime': 1560193200,
#     'apparentTemperatureLow': 79.78,
#     'apparentTemperatureLowTime': 1560240000,
#     'dewPoint': 73.06,
#     'humidity': 0.71,
#     'pressure': 1016.62,
#     'windSpeed': 7.98,
#     'windGust': 15.07,
#     'windGustTime': 1560204000,
#     'windBearing': 175,
#     'cloudCover': 0.49,
#     'uvIndex': 9,
#     'uvIndexTime': 1560186000,
#     'visibility': 10,
#     'ozone': 295.14,
#     'temperatureMin': 77.06,
#     'temperatureMinTime': 1560153600,
#     'temperatureMax': 91.15,
#     'temperatureMaxTime': 1560193200,
#     'apparentTemperatureMin': 78.7,
#     'apparentTemperatureMinTime': 1560153600,
#     'apparentTemperatureMax': 98.76,
#     'apparentTemperatureMaxTime': 1560193200},
#    {'time': 1560225600,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560249015,
#     'sunsetTime': 1560298409,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0006,
#     'precipIntensityMax': 0.0043,
#     'precipIntensityMaxTime': 1560254400,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'temperatureHigh': 90.94,
#     'temperatureHighTime': 1560276000,
#     'temperatureLow': 79.04,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 96.44,
#     'apparentTemperatureHighTime': 1560276000,
#     'apparentTemperatureLow': 81.99,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 71.35,
#     'humidity': 0.67,
#     'pressure': 1016.41,
#     'windSpeed': 7.29,
#     'windGust': 13.59,
#     'windGustTime': 1560290400,
#     'windBearing': 140,
#     'cloudCover': 0.75,
#     'uvIndex': 5,
#     'uvIndexTime': 1560268800,
#     'visibility': 10,
#     'ozone': 294.81,
#     'temperatureMin': 78.3,
#     'temperatureMinTime': 1560240000,
#     'temperatureMax': 90.94,
#     'temperatureMaxTime': 1560276000,
#     'apparentTemperatureMin': 79.78,
#     'apparentTemperatureMinTime': 1560240000,
#     'apparentTemperatureMax': 96.44,
#     'apparentTemperatureMaxTime': 1560276000},
#    {'time': 1560312000,
#     'summary': 'Mostly cloudy in the morning and humid throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560335417,
#     'sunsetTime': 1560384830,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0016,
#     'precipIntensityMax': 0.0066,
#     'precipIntensityMaxTime': 1560394800,
#     'precipProbability': 0.28,
#     'precipType': 'rain',
#     'temperatureHigh': 90.12,
#     'temperatureHighTime': 1560362400,
#     'temperatureLow': 77.93,
#     'temperatureLowTime': 1560416400,
#     'apparentTemperatureHigh': 96.86,
#     'apparentTemperatureHighTime': 1560369600,
#     'apparentTemperatureLow': 79.28,
#     'apparentTemperatureLowTime': 1560416400,
#     'dewPoint': 71.24,
#     'humidity': 0.66,
#     'pressure': 1016.1,
#     'windSpeed': 7.86,
#     'windGust': 14.16,
#     'windGustTime': 1560376800,
#     'windBearing': 144,
#     'cloudCover': 0.52,
#     'uvIndex': 10,
#     'uvIndexTime': 1560358800,
#     'visibility': 10,
#     'ozone': 301.78,
#     'temperatureMin': 79.04,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 90.12,
#     'temperatureMaxTime': 1560362400,
#     'apparentTemperatureMin': 81.99,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 96.86,
#     'apparentTemperatureMaxTime': 1560369600},
#    {'time': 1560398400,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560421821,
#     'sunsetTime': 1560471250,
#     'moonPhase': 0.38,
#     'precipIntensity': 0.0024,
#     'precipIntensityMax': 0.0088,
#     'precipIntensityMaxTime': 1560402000,
#     'precipProbability': 0.41,
#     'precipType': 'rain',
#     'temperatureHigh': 90.48,
#     'temperatureHighTime': 1560448800,
#     'temperatureLow': 78.84,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 97.26,
#     'apparentTemperatureHighTime': 1560448800,
#     'apparentTemperatureLow': 82.01,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 71.94,
#     'humidity': 0.68,
#     'pressure': 1016.88,
#     'windSpeed': 7.04,
#     'windGust': 13.9,
#     'windGustTime': 1560459600,
#     'windBearing': 176,
#     'cloudCover': 0.64,
#     'uvIndex': 8,
#     'uvIndexTime': 1560445200,
#     'visibility': 10,
#     'ozone': 283.32,
#     'temperatureMin': 77.93,
#     'temperatureMinTime': 1560416400,
#     'temperatureMax': 90.48,
#     'temperatureMaxTime': 1560448800,
#     'apparentTemperatureMin': 79.28,
#     'apparentTemperatureMinTime': 1560416400,
#     'apparentTemperatureMax': 97.26,
#     'apparentTemperatureMaxTime': 1560448800},
#    {'time': 1560484800,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560508225,
#     'sunsetTime': 1560557669,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.0091,
#     'precipIntensityMax': 0.0373,
#     'precipIntensityMaxTime': 1560556800,
#     'precipProbability': 0.73,
#     'precipType': 'rain',
#     'temperatureHigh': 89.21,
#     'temperatureHighTime': 1560535200,
#     'temperatureLow': 78.35,
#     'temperatureLowTime': 1560596400,
#     'apparentTemperatureHigh': 96.67,
#     'apparentTemperatureHighTime': 1560535200,
#     'apparentTemperatureLow': 79.85,
#     'apparentTemperatureLowTime': 1560596400,
#     'dewPoint': 72.66,
#     'humidity': 0.7,
#     'pressure': 1017.49,
#     'windSpeed': 5.99,
#     'windGust': 11.88,
#     'windGustTime': 1560567600,
#     'windBearing': 127,
#     'cloudCover': 0.87,
#     'uvIndex': 5,
#     'uvIndexTime': 1560528000,
#     'visibility': 9.26,
#     'ozone': 281.98,
#     'temperatureMin': 78.84,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 89.21,
#     'temperatureMaxTime': 1560535200,
#     'apparentTemperatureMin': 82.01,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 96.67,
#     'apparentTemperatureMaxTime': 1560535200}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.805,
#   'units': 'us'},
#  'offset': -4}

# %%
Miami24 = Miami['hourly']['data']
Miami24
# Out:
# [{'time': 1559955600,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0131,
#   'precipProbability': 0.38,
#   'precipType': 'rain',
#   'temperature': 77.4,
#   'apparentTemperature': 78.99,
#   'dewPoint': 73.62,
#   'humidity': 0.88,
#   'pressure': 1012.58,
#   'windSpeed': 6.43,
#   'windGust': 8.41,
#   'windBearing': 99,
#   'cloudCover': 0.92,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 280.74},
#  {'time': 1559959200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0094,
#   'precipProbability': 0.32,
#   'precipType': 'rain',
#   'temperature': 77.63,
#   'apparentTemperature': 79.24,
#   'dewPoint': 73.87,
#   'humidity': 0.88,
#   'pressure': 1012.62,
#   'windSpeed': 6.09,
#   'windGust': 8.06,
#   'windBearing': 103,
#   'cloudCover': 0.73,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 281.01},
#  {'time': 1559962800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0121,
#   'precipProbability': 0.17,
#   'precipType': 'rain',
#   'temperature': 80.22,
#   'apparentTemperature': 85.08,
#   'dewPoint': 74.42,
#   'humidity': 0.83,
#   'pressure': 1012.52,
#   'windSpeed': 5.75,
#   'windGust': 7.77,
#   'windBearing': 153,
#   'cloudCover': 0.51,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 281.22},
#  {'time': 1559966400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0045,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 81.77,
#   'apparentTemperature': 88.04,
#   'dewPoint': 74.68,
#   'humidity': 0.79,
#   'pressure': 1012.28,
#   'windSpeed': 8.02,
#   'windGust': 10.28,
#   'windBearing': 179,
#   'cloudCover': 0.4,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 281.64},
#  {'time': 1559970000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0024,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 81.43,
#   'apparentTemperature': 87.42,
#   'dewPoint': 74.64,
#   'humidity': 0.8,
#   'pressure': 1012.49,
#   'windSpeed': 8.5,
#   'windGust': 10.91,
#   'windBearing': 182,
#   'cloudCover': 0.33,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 282.02},
#  {'time': 1559973600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0034,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 79.62,
#   'apparentTemperature': 84,
#   'dewPoint': 74.68,
#   'humidity': 0.85,
#   'pressure': 1012.48,
#   'windSpeed': 8.87,
#   'windGust': 11.98,
#   'windBearing': 184,
#   'cloudCover': 0.32,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 282.49},
#  {'time': 1559977200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0041,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 77.72,
#   'apparentTemperature': 79.45,
#   'dewPoint': 74.73,
#   'humidity': 0.91,
#   'pressure': 1012.29,
#   'windSpeed': 9.28,
#   'windGust': 13.1,
#   'windBearing': 186,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 282.89},
#  {'time': 1559980800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0039,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 76.76,
#   'apparentTemperature': 78.52,
#   'dewPoint': 74.63,
#   'humidity': 0.93,
#   'pressure': 1012.01,
#   'windSpeed': 9.51,
#   'windGust': 14.14,
#   'windBearing': 189,
#   'cloudCover': 0.41,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 283.41},
#  {'time': 1559984400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0047,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 76.58,
#   'apparentTemperature': 78.38,
#   'dewPoint': 74.88,
#   'humidity': 0.95,
#   'pressure': 1012.02,
#   'windSpeed': 9.5,
#   'windGust': 14.95,
#   'windBearing': 192,
#   'cloudCover': 0.43,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 283.87},
#  {'time': 1559988000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0049,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 77.06,
#   'apparentTemperature': 78.86,
#   'dewPoint': 74.98,
#   'humidity': 0.93,
#   'pressure': 1012.27,
#   'windSpeed': 9.15,
#   'windGust': 14.97,
#   'windBearing': 198,
#   'cloudCover': 0.42,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 284.03},
#  {'time': 1559991600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0053,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 77.82,
#   'apparentTemperature': 79.61,
#   'dewPoint': 75.21,
#   'humidity': 0.92,
#   'pressure': 1012.59,
#   'windSpeed': 8.59,
#   'windGust': 14.92,
#   'windBearing': 204,
#   'cloudCover': 0.35,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 284.25},
#  {'time': 1559995200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0054,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 79.43,
#   'apparentTemperature': 83.83,
#   'dewPoint': 75.37,
#   'humidity': 0.87,
#   'pressure': 1013.02,
#   'windSpeed': 8.07,
#   'windGust': 14.31,
#   'windBearing': 211,
#   'cloudCover': 0.34,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 284.58},
#  {'time': 1559998800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0035,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 82.07,
#   'apparentTemperature': 88.76,
#   'dewPoint': 74.96,
#   'humidity': 0.79,
#   'pressure': 1013.46,
#   'windSpeed': 7.66,
#   'windGust': 12.49,
#   'windBearing': 210,
#   'cloudCover': 0.28,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 285.25},
#  {'time': 1560002400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0016,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 84.49,
#   'apparentTemperature': 91.96,
#   'dewPoint': 74.1,
#   'humidity': 0.71,
#   'pressure': 1013.97,
#   'windSpeed': 6.83,
#   'windGust': 10.23,
#   'windBearing': 206,
#   'cloudCover': 0.26,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 286.13},
#  {'time': 1560006000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0013,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 86.59,
#   'apparentTemperature': 93.79,
#   'dewPoint': 72.86,
#   'humidity': 0.64,
#   'pressure': 1014.51,
#   'windSpeed': 6.29,
#   'windGust': 7.93,
#   'windBearing': 193,
#   'cloudCover': 0.37,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 286.79},
#  {'time': 1560009600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0051,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 87.33,
#   'apparentTemperature': 94.67,
#   'dewPoint': 72.76,
#   'humidity': 0.62,
#   'pressure': 1014.53,
#   'windSpeed': 7.05,
#   'windGust': 8.11,
#   'windBearing': 184,
#   'cloudCover': 0.45,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 286.84},
#  {'time': 1560013200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0196,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 89.86,
#   'apparentTemperature': 98.04,
#   'dewPoint': 72.87,
#   'humidity': 0.58,
#   'pressure': 1014.32,
#   'windSpeed': 8.35,
#   'windGust': 9.17,
#   'windBearing': 174,
#   'cloudCover': 0.58,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 286.87},
#  {'time': 1560016800,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0351,
#   'precipProbability': 0.19,
#   'precipType': 'rain',
#   'temperature': 91.33,
#   'apparentTemperature': 100.02,
#   'dewPoint': 72.96,
#   'humidity': 0.55,
#   'pressure': 1014.05,
#   'windSpeed': 9.41,
#   'windGust': 10.23,
#   'windBearing': 168,
#   'cloudCover': 0.67,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 286.69},
#  {'time': 1560020400,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.038,
#   'precipProbability': 0.22,
#   'precipType': 'rain',
#   'temperature': 91.54,
#   'apparentTemperature': 100.23,
#   'dewPoint': 72.91,
#   'humidity': 0.55,
#   'pressure': 1013.71,
#   'windSpeed': 10.12,
#   'windGust': 11.17,
#   'windBearing': 170,
#   'cloudCover': 0.7,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 286.47},
#  {'time': 1560024000,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0342,
#   'precipProbability': 0.24,
#   'precipType': 'rain',
#   'temperature': 90.78,
#   'apparentTemperature': 99.21,
#   'dewPoint': 72.86,
#   'humidity': 0.56,
#   'pressure': 1013.29,
#   'windSpeed': 10.59,
#   'windGust': 12.12,
#   'windBearing': 176,
#   'cloudCover': 0.71,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 286.2},
#  {'time': 1560027600,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0292,
#   'precipProbability': 0.24,
#   'precipType': 'rain',
#   'temperature': 89.62,
#   'apparentTemperature': 97.69,
#   'dewPoint': 72.82,
#   'humidity': 0.58,
#   'pressure': 1013.08,
#   'windSpeed': 10.68,
#   'windGust': 12.45,
#   'windBearing': 179,
#   'cloudCover': 0.71,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 286.19},
#  {'time': 1560031200,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.025,
#   'precipProbability': 0.23,
#   'precipType': 'rain',
#   'temperature': 88.2,
#   'apparentTemperature': 95.92,
#   'dewPoint': 72.87,
#   'humidity': 0.61,
#   'pressure': 1013.17,
#   'windSpeed': 10.07,
#   'windGust': 11.71,
#   'windBearing': 174,
#   'cloudCover': 0.69,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 286.51},
#  {'time': 1560034800,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0255,
#   'precipProbability': 0.22,
#   'precipType': 'rain',
#   'temperature': 87.03,
#   'apparentTemperature': 94.47,
#   'dewPoint': 72.96,
#   'humidity': 0.63,
#   'pressure': 1013.47,
#   'windSpeed': 9.03,
#   'windGust': 10.43,
#   'windBearing': 167,
#   'cloudCover': 0.67,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 286.97},
#  {'time': 1560038400,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0257,
#   'precipProbability': 0.2,
#   'precipType': 'rain',
#   'temperature': 85.86,
#   'apparentTemperature': 93.01,
#   'dewPoint': 73.07,
#   'humidity': 0.66,
#   'pressure': 1013.83,
#   'windSpeed': 8.34,
#   'windGust': 9.76,
#   'windBearing': 164,
#   'cloudCover': 0.64,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 287.63},
#  {'time': 1560042000,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0145,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 84.95,
#   'apparentTemperature': 91.84,
#   'dewPoint': 73.17,
#   'humidity': 0.68,
#   'pressure': 1014.31,
#   'windSpeed': 8.33,
#   'windGust': 10.23,
#   'windBearing': 167,
#   'cloudCover': 0.62,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.18},
#  {'time': 1560045600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0032,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 84.01,
#   'apparentTemperature': 90.61,
#   'dewPoint': 73.28,
#   'humidity': 0.7,
#   'pressure': 1014.87,
#   'windSpeed': 8.58,
#   'windGust': 11.12,
#   'windBearing': 171,
#   'cloudCover': 0.57,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.93},
#  {'time': 1560049200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0003,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 83.14,
#   'apparentTemperature': 89.44,
#   'dewPoint': 73.45,
#   'humidity': 0.73,
#   'pressure': 1015.21,
#   'windSpeed': 8.67,
#   'windGust': 11.75,
#   'windBearing': 175,
#   'cloudCover': 0.54,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 289.69},
#  {'time': 1560052800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0004,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 82.43,
#   'apparentTemperature': 88.44,
#   'dewPoint': 73.58,
#   'humidity': 0.75,
#   'pressure': 1015.23,
#   'windSpeed': 8.53,
#   'windGust': 11.91,
#   'windBearing': 177,
#   'cloudCover': 0.54,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 290.69},
#  {'time': 1560056400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0008,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 82.1,
#   'apparentTemperature': 88.01,
#   'dewPoint': 73.73,
#   'humidity': 0.76,
#   'pressure': 1015.03,
#   'windSpeed': 8.31,
#   'windGust': 11.91,
#   'windBearing': 177,
#   'cloudCover': 0.54,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 291.65},
#  {'time': 1560060000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0014,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 80.21,
#   'apparentTemperature': 84.88,
#   'dewPoint': 73.95,
#   'humidity': 0.81,
#   'pressure': 1014.81,
#   'windSpeed': 8.09,
#   'windGust': 11.93,
#   'windBearing': 179,
#   'cloudCover': 0.55,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 292.66},
#  {'time': 1560063600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0033,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 78.59,
#   'apparentTemperature': 81.76,
#   'dewPoint': 74.29,
#   'humidity': 0.87,
#   'pressure': 1014.52,
#   'windSpeed': 7.93,
#   'windGust': 12.12,
#   'windBearing': 183,
#   'cloudCover': 0.51,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 293.47},
#  {'time': 1560067200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0111,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 78.06,
#   'apparentTemperature': 79.77,
#   'dewPoint': 74.66,
#   'humidity': 0.89,
#   'pressure': 1014.19,
#   'windSpeed': 7.79,
#   'windGust': 12.37,
#   'windBearing': 189,
#   'cloudCover': 0.46,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.05},
#  {'time': 1560070800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0172,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 78.06,
#   'apparentTemperature': 79.8,
#   'dewPoint': 74.88,
#   'humidity': 0.9,
#   'pressure': 1014.06,
#   'windSpeed': 7.67,
#   'windGust': 12.61,
#   'windBearing': 191,
#   'cloudCover': 0.41,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 294.79},
#  {'time': 1560074400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0102,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 78.18,
#   'apparentTemperature': 79.9,
#   'dewPoint': 74.81,
#   'humidity': 0.89,
#   'pressure': 1014.34,
#   'windSpeed': 7.57,
#   'windGust': 12.86,
#   'windBearing': 189,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 295.74},
#  {'time': 1560078000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.002,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 78.49,
#   'apparentTemperature': 81.59,
#   'dewPoint': 74.62,
#   'humidity': 0.88,
#   'pressure': 1014.82,
#   'windSpeed': 7.5,
#   'windGust': 13.07,
#   'windBearing': 185,
#   'cloudCover': 0.3,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 296.71},
#  {'time': 1560081600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 79.48,
#   'apparentTemperature': 83.62,
#   'dewPoint': 74.37,
#   'humidity': 0.84,
#   'pressure': 1015.34,
#   'windSpeed': 7.54,
#   'windGust': 12.98,
#   'windBearing': 182,
#   'cloudCover': 0.26,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 297.52},
#  {'time': 1560085200,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0006,
#   'precipProbability': 0.06,
#   'precipType': 'rain',
#   'temperature': 81.92,
#   'apparentTemperature': 87.93,
#   'dewPoint': 74.09,
#   'humidity': 0.77,
#   'pressure': 1015.87,
#   'windSpeed': 7.63,
#   'windGust': 12.25,
#   'windBearing': 179,
#   'cloudCover': 0.22,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 298.26},
#  {'time': 1560088800,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0028,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 83.98,
#   'apparentTemperature': 90.95,
#   'dewPoint': 73.79,
#   'humidity': 0.72,
#   'pressure': 1016.42,
#   'windSpeed': 7.84,
#   'windGust': 11.25,
#   'windBearing': 175,
#   'cloudCover': 0.19,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 298.74},
#  {'time': 1560092400,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0047,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 85.67,
#   'apparentTemperature': 93.15,
#   'dewPoint': 73.53,
#   'humidity': 0.67,
#   'pressure': 1016.77,
#   'windSpeed': 8.3,
#   'windGust': 10.73,
#   'windBearing': 173,
#   'cloudCover': 0.18,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 298.92},
#  {'time': 1560096000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0033,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 86.91,
#   'apparentTemperature': 94.6,
#   'dewPoint': 73.27,
#   'humidity': 0.64,
#   'pressure': 1016.79,
#   'windSpeed': 9.11,
#   'windGust': 11,
#   'windBearing': 170,
#   'cloudCover': 0.25,
#   'uvIndex': 9,
#   'visibility': 10,
#   'ozone': 298.54},
#  {'time': 1560099600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.09,
#   'precipType': 'rain',
#   'temperature': 89.6,
#   'apparentTemperature': 97.83,
#   'dewPoint': 72.99,
#   'humidity': 0.58,
#   'pressure': 1016.59,
#   'windSpeed': 10.12,
#   'windGust': 11.68,
#   'windBearing': 167,
#   'cloudCover': 0.35,
#   'uvIndex': 9,
#   'visibility': 10,
#   'ozone': 297.76},
#  {'time': 1560103200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0031,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'temperature': 91.16,
#   'apparentTemperature': 99.61,
#   'dewPoint': 72.78,
#   'humidity': 0.55,
#   'pressure': 1016.32,
#   'windSpeed': 10.95,
#   'windGust': 12.47,
#   'windBearing': 167,
#   'cloudCover': 0.43,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 297.09},
#  {'time': 1560106800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.003,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'temperature': 91.42,
#   'apparentTemperature': 99.8,
#   'dewPoint': 72.66,
#   'humidity': 0.54,
#   'pressure': 1015.89,
#   'windSpeed': 11.47,
#   'windGust': 13.39,
#   'windBearing': 169,
#   'cloudCover': 0.47,
#   'uvIndex': 7,
#   'visibility': 10,
#   'ozone': 296.49},
#  {'time': 1560110400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0046,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 90.58,
#   'apparentTemperature': 98.67,
#   'dewPoint': 72.59,
#   'humidity': 0.56,
#   'pressure': 1015.41,
#   'windSpeed': 11.82,
#   'windGust': 14.4,
#   'windBearing': 172,
#   'cloudCover': 0.49,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 295.87},
#  {'time': 1560114000,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0075,
#   'precipProbability': 0.13,
#   'precipType': 'rain',
#   'temperature': 89.47,
#   'apparentTemperature': 97.25,
#   'dewPoint': 72.59,
#   'humidity': 0.58,
#   'pressure': 1015.12,
#   'windSpeed': 11.92,
#   'windGust': 15.02,
#   'windBearing': 174,
#   'cloudCover': 0.5,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 295.55},
#  {'time': 1560117600,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0088,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 87.9,
#   'apparentTemperature': 95.36,
#   'dewPoint': 72.7,
#   'humidity': 0.61,
#   'pressure': 1015.24,
#   'windSpeed': 11.74,
#   'windGust': 15.13,
#   'windBearing': 178,
#   'cloudCover': 0.48,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 295.7},
#  {'time': 1560121200,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0103,
#   'precipProbability': 0.15,
#   'precipType': 'rain',
#   'temperature': 86.66,
#   'apparentTemperature': 93.89,
#   'dewPoint': 72.86,
#   'humidity': 0.64,
#   'pressure': 1015.56,
#   'windSpeed': 11.36,
#   'windGust': 14.88,
#   'windBearing': 181,
#   'cloudCover': 0.47,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 296.06},
#  {'time': 1560124800,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0114,
#   'precipProbability': 0.15,
#   'precipType': 'rain',
#   'temperature': 85.59,
#   'apparentTemperature': 92.6,
#   'dewPoint': 73.03,
#   'humidity': 0.66,
#   'pressure': 1015.89,
#   'windSpeed': 10.88,
#   'windGust': 14.58,
#   'windBearing': 183,
#   'cloudCover': 0.45,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 296.39},
#  {'time': 1560128400,
#   'summary': 'Humid and Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.009,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 84.81,
#   'apparentTemperature': 91.62,
#   'dewPoint': 73.14,
#   'humidity': 0.68,
#   'pressure': 1016.33,
#   'windSpeed': 10.16,
#   'windGust': 14.23,
#   'windBearing': 181,
#   'cloudCover': 0.35,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 296.88}]

# %%
for hour in Miami24:
    temp = hour['temperature']
    if hour['cloudCover'] > 0.5:
        print(temp,"and cloudy")
    else:
        print(temp)
# Out:
# 77.4 and cloudy
# 77.63 and cloudy
# 80.22 and cloudy
# 81.77
# 81.43
# 79.62
# 77.72
# 76.76
# 76.58
# 77.06
# 77.82
# 79.43
# 82.07
# 84.49
# 86.59
# 87.33
# 89.86 and cloudy
# 91.33 and cloudy
# 91.54 and cloudy
# 90.78 and cloudy
# 89.62 and cloudy
# 88.2 and cloudy
# 87.03 and cloudy
# 85.86 and cloudy
# 84.95 and cloudy
# 84.01 and cloudy
# 83.14 and cloudy
# 82.43 and cloudy
# 82.1 and cloudy
# 80.21 and cloudy
# 78.59 and cloudy
# 78.06
# 78.06
# 78.18
# 78.49
# 79.48
# 81.92
# 83.98
# 85.67
# 86.91
# 89.6
# 91.16
# 91.42
# 90.58
# 89.47
# 87.9
# 86.66
# 85.59
# 84.81

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
Above85 = []
MiamiTemp = []
for hour in Miami24:
    temp = hour['temperature']
    MiamiTemp.append(temp)
    if hour['temperature'] > 85:
        Above85.append(temp)
Percentage = f'{round(len(Above85)/len(MiamiTemp)*100,2)}%'
Percentage
# Out:
# '40.82%'

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1356393600')
CP_2012Christmas = response.json()
CP_2012Christmas['currently']['temperature']
# Out:
# 36.81

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1198540800')
CP_2007Christmas = response.json()
CP_2007Christmas['currently']['temperature']
# Out:
# 41.25

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1135468800')
CP_2005Christmas = response.json()
CP_2005Christmas['currently']['temperature']
# Out:
# 42.88

# %%
# The earliest time: 02/01/1940, 3：00 am
